# %%
import matplotlib.pyplot as plt
import numpy as np
import pyreadr
import pyro

# %%
df = pyreadr.read_r('data/data.Rda')[None]
df.head().style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_6f86b">
#   <thead>
#     <tr>
#       <th id="T_6f86b_level0_col0" class="col_heading level0 col0" >y</th>
#       <th id="T_6f86b_level0_col1" class="col_heading level0 col1" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6f86b_row0_col0" class="data row0 col0" >0.795570</td>
#       <td id="T_6f86b_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_6f86b_row1_col0" class="data row1 col0" >0.174560</td>
#       <td id="T_6f86b_row1_col1" class="data row1 col1" >0.500000</td>
#     </tr>
#     <tr>
#       <td id="T_6f86b_row2_col0" class="data row2 col0" >0.774322</td>
#       <td id="T_6f86b_row2_col1" class="data row2 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_6f86b_row3_col0" class="data row3 col0" >3.083851</td>
#       <td id="T_6f86b_row3_col1" class="data row3 col1" >1.500000</td>
#     </tr>
#     <tr>
#       <td id="T_6f86b_row4_col0" class="data row4 col0" >2.163227</td>
#       <td id="T_6f86b_row4_col1" class="data row4 col1" >2.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.grid(alpha=.5)
ax.scatter(df['time'], df['y'], s=100, zorder=2)
ax.set_xlabel('Time')
ax.set_ylabel(ylabel='y', rotation=0.)
fig.tight_layout()
